# %%
#0: Importar bibliotecas
import cv2
import matplotlib.pyplot as plt

# %%
#1: Faça upload da sua imagem

#2: Defina o nome da sua imagem (escreva igualzinho o nome do arquivo)


#3: Crie a variavel imagem
imagem =

# %%
#4: Faça um print da imagem

# %%
#5 Exiba a imagem

# %%
#6 Alternando os espaço de cores para RGB

# %%
#7 Exibindo a imagem

# %%
cv2.imshow("Marque uma laranja", imagem)

x, y, w, h = cv2.selectROI(
    "Marque uma laranja",
    imagem,
    fromCenter=False,
    showCrosshair=True
)

cv2.destroyAllWindows()

print("x =", x)
print("y =", y)
print("largura =", w)
print("altura =", h)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 cv2.imshow("Marque uma laranja", imagem)
#       3 x, y, w, h = cv2.selectROI(
#       4     "Marque uma laranja",
#       5     imagem,
#       6     fromCenter=False,
#       7     showCrosshair=True
#       8 )
#      10 cv2.destroyAllWindows()
#
# NameError: name 'imagem' is not defined

# %%
#8 Observando características
imagem_rgb.shape

# %%
x1 = 757
y1 = 95
largura_box1 = 153
altura_box1 = 160

# %%
# Desenhando Bounding Boxes na imagem

imagem_box = imagem.copy()

plt.imshow(imagem_box_rgb)
